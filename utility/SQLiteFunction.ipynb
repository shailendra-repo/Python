# %%
import sqlite3
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.options.display.width = None

dbName = 'Data'
con = sqlite3.connect(dbName+'.db')

sqlCmd = 'select name from sqlite_master where type=\'table\';'
tableList = pd.read_sql_query(sqlCmd,con)

while sqlCmd != 'exit':
    try:
        if(sqlCmd =='1'):
            sqlCmd = 'select name from sqlite_master where type=\'table\';'
            
        result = pd.read_sql_query(sqlCmd, con)
        print('----------------------------------------------------------------------------------------')
        print(result.to_string())
        result.to_string()
        result.to_excel('sqlResult.xlsx')
        sqlCmd = input('SQL> ')
        
    except Exception as e:
        print('')
        print(e)
        print('An exception happened. Look at the query')
        sqlCmd = input('SQL> ')
        
con.close()
# Out:
# ----------------------------------------------------------------------------------------
#         name
# 0  reddit_vm
# SQL> select * from reddit_vm limit 2;
# ----------------------------------------------------------------------------------------
#    index                                                                           title  score      id                                                                          url  comms_num       created  body            timestamp
# 0      0                             Health Canada approves AstraZeneca COVID-19 vaccine      7  lt74vw  https://www.canadaforums.ca/2021/02/health-canada-approves-astrazeneca.html          0  1.614400e+09  None  2021-02-27 06:33:45
# 1      1  COVID-19 in Canada: 'Vaccination passports' a near certainty says bio-ethicist      2  lsh0ij      https://www.canadaforums.ca/2021/02/covid-19-in-canada-vaccination.html          1  1.614316e+09  None  2021-02-26 07:11:07
# SQL> select * from reddig_vm where 1=2
#
# ...

# %%
import sqlite3
import pandas as pd

dbName = 'Data'
con = sqlite3.connect(dbName+'.db')

alldata = pd.read_csv('data/reddit_vm.csv')
alldata.to_sql('reddit_vm',con, index=False,if_exists='replace')
con.close()

# %%
def loadCsv(con, fileName, tableName):
    alldata = pd.read_csv(fileName)
    alldata.to_sql(tableName,con, index=False,if_exists='replace')

def selectData(con, query):

    sqlCmd = query
    tableList = pd.read_sql_query(sqlCmd,con)

    result = pd.read_sql_query(sqlCmd, con)

    return result

def SelectDataToTable(con, query, tableName):

    sqlCmd = query
    tableList = pd.read_sql_query(sqlCmd,con)

    result = pd.read_sql_query(sqlCmd, con)
    result.to_sql(tableName ,con, index=False,if_exists='replace')

    
def queryData(con):

    sqlCmd = 'select name from sqlite_master where type=\'table\';'
    tableList = pd.read_sql_query(sqlCmd,con)

    while sqlCmd != 'exit':
        try:
            if(sqlCmd =='1'):
                sqlCmd = 'select name from sqlite_master where type=\'table\';'

            result = pd.read_sql_query(sqlCmd, con)
            print('----------------------------------------------------------------------------------------')
            print(result.to_string())
            
            sqlCmd = input('SQL> ')

        except Exception as e:
            print('')
            print(e)
            print('An exception happened. Look at the query')
            sqlCmd = input('SQL> ')

def dropTable(con, tableName):
    con.execute('drop table \''+tableName + '\'')
    
def execQuery(con, qry):
    ds = con.execute(qry)

# %%
selectData(con,'select * from reddit_vm limit 2')
# Out:
#                                                title  score      id  \
# 0  Health Canada approves AstraZeneca COVID-19 va...     10  lt74vw
# 1  COVID-19 in Canada: 'Vaccination passports' a ...      2  lsh0ij
#
#                                                  url  comms_num       created  \
# 0  https://www.canadaforums.ca/2021/02/health-can...          0  1.614400e+09
# 1  https://www.canadaforums.ca/2021/02/covid-19-i...          1  1.614316e+09
#
#    body            timestamp
# 0  None  2021-02-27 06:33:45
# 1  None  2021-02-26 07:11:07

# %%
loadCsv(con,'data/reddit_vm.csv','reddit')

# %%
selectData(con, 'select * from reddit limit 3')
# Out:
#                                                title  score      id  \
# 0  Health Canada approves AstraZeneca COVID-19 va...      7  lt74vw
# 1  COVID-19 in Canada: 'Vaccination passports' a ...      2  lsh0ij
# 2  Coronavirus variants could fuel Canada's third...      6  lohlle
#
#                                                  url  comms_num       created  \
# 0  https://www.canadaforums.ca/2021/02/health-can...          0  1.614400e+09
# 1  https://www.canadaforums.ca/2021/02/covid-19-i...          1  1.614316e+09
# 2  https://www.canadaforums.ca/2021/02/coronaviru...          0  1.613887e+09
#
#    body            timestamp
# 0  None  2021-02-27 06:33:45
# 1  None  2021-02-26 07:11:07
# 2  None  2021-02-21 07:50:08

# %%
dbName = 'Data'
con = sqlite3.connect(dbName+'.db')

data = selectData(con,'select * from reddit_vm limit 2')
con.close()

data
# Out:
#                                                title  score      id  \
# 0  Health Canada approves AstraZeneca COVID-19 va...      7  lt74vw
# 1  COVID-19 in Canada: 'Vaccination passports' a ...      2  lsh0ij
#
#                                                  url  comms_num       created  \
# 0  https://www.canadaforums.ca/2021/02/health-can...          0  1.614400e+09
# 1  https://www.canadaforums.ca/2021/02/covid-19-i...          1  1.614316e+09
#
#    body            timestamp
# 0  None  2021-02-27 06:33:45
# 1  None  2021-02-26 07:11:07

# %%
dbName = 'Data'
con = sqlite3.connect(dbName+'.db')

# %%
selectData(con, 'select * from reddit_vm limit 10')
# Out:
#                                                title  score       id  \
# 0  Health Canada approves AstraZeneca COVID-19 va...      7   lt74vw
# 1  COVID-19 in Canada: 'Vaccination passports' a ...      2   lsh0ij
# 2  Coronavirus variants could fuel Canada's third...      6   lohlle
# 3  Canadian government to extend COVID-19 emergen...      1   lnptv8
# 4  Canada: Pfizer is 'extremely committed' to mee...      6   lkslm6
# 5  Canada: Oxford-AstraZeneca vaccine approval ex...      5   lftbji
# 6                                            Comment      1  ej9x066
# 7                      Fuck you anti-vaxxing retards     10   g6jkhp
# 8                                            Comment      0  fofa0yy
# 9                                            Comment      0  ej9xuaf
#
#                                                  url  comms_num       created  \
# 0  https://www.canadaforums.ca/2021/02/health-can...          0  1.614400e+09
# ...

# %%
selectData(con, 'select * from reddit_vm limit 15')
# Out:
#                                                 title  score       id  \
# 0   Health Canada approves AstraZeneca COVID-19 va...      7   lt74vw
# 1   COVID-19 in Canada: 'Vaccination passports' a ...      2   lsh0ij
# 2   Coronavirus variants could fuel Canada's third...      6   lohlle
# 3   Canadian government to extend COVID-19 emergen...      1   lnptv8
# 4   Canada: Pfizer is 'extremely committed' to mee...      6   lkslm6
# 5   Canada: Oxford-AstraZeneca vaccine approval ex...      5   lftbji
# 6                                             Comment      1  ej9x066
# 7                       Fuck you anti-vaxxing retards     10   g6jkhp
# 8                                             Comment      0  fofa0yy
# 9                                             Comment      0  ej9xuaf
# 10                                            Comment      1  ej9x2qr
# 11                                            Comment      2  ejacj98
# ...

# %%
selectData(con, 'select * from reddit_vm limit 10')
# Out:
#                                                title  score       id  \
# 0  Health Canada approves AstraZeneca COVID-19 va...      7   lt74vw
# 1  COVID-19 in Canada: 'Vaccination passports' a ...      2   lsh0ij
# 2  Coronavirus variants could fuel Canada's third...      6   lohlle
# 3  Canadian government to extend COVID-19 emergen...      1   lnptv8
# 4  Canada: Pfizer is 'extremely committed' to mee...      6   lkslm6
# 5  Canada: Oxford-AstraZeneca vaccine approval ex...      5   lftbji
# 6                                            Comment      1  ej9x066
# 7                      Fuck you anti-vaxxing retards     10   g6jkhp
# 8                                            Comment      0  fofa0yy
# 9                                            Comment      0  ej9xuaf
#
#                                                  url  comms_num       created  \
# 0  https://www.canadaforums.ca/2021/02/health-can...          0  1.614400e+09
# ...

# %%
selectData(con, 'select * from reddit_vm limit 5')
# Out:
#                                                title  score      id  \
# 0  Health Canada approves AstraZeneca COVID-19 va...      7  lt74vw
# 1  COVID-19 in Canada: 'Vaccination passports' a ...      2  lsh0ij
# 2  Coronavirus variants could fuel Canada's third...      6  lohlle
# 3  Canadian government to extend COVID-19 emergen...      1  lnptv8
# 4  Canada: Pfizer is 'extremely committed' to mee...      6  lkslm6
#
#                                                  url  comms_num       created  \
# 0  https://www.canadaforums.ca/2021/02/health-can...          0  1.614400e+09
# 1  https://www.canadaforums.ca/2021/02/covid-19-i...          1  1.614316e+09
# 2  https://www.canadaforums.ca/2021/02/coronaviru...          0  1.613887e+09
# 3  https://www.canadaforums.ca/2021/02/canadian-g...          0  1.613796e+09
# 4  https://www.canadaforums.ca/2021/02/canada-pfi...          0  1.613468e+09
#
#    body            timestamp
# 0  None  2021-02-27 06:33:45
# ...

# %%
SelectDataToTable(con,'select * from reddit_vm limit 10','newtable')

# %%
selectData(con, 'select * from newtable')
# Out:
#                                                title  score       id  \
# 0  Health Canada approves AstraZeneca COVID-19 va...      7   lt74vw
# 1  COVID-19 in Canada: 'Vaccination passports' a ...      2   lsh0ij
# 2  Coronavirus variants could fuel Canada's third...      6   lohlle
# 3  Canadian government to extend COVID-19 emergen...      1   lnptv8
# 4  Canada: Pfizer is 'extremely committed' to mee...      6   lkslm6
# 5  Canada: Oxford-AstraZeneca vaccine approval ex...      5   lftbji
# 6                                            Comment      1  ej9x066
# 7                      Fuck you anti-vaxxing retards     10   g6jkhp
# 8                                            Comment      0  fofa0yy
# 9                                            Comment      0  ej9xuaf
#
#                                                  url  comms_num       created  \
# 0  https://www.canadaforums.ca/2021/02/health-can...          0  1.614400e+09
# ...

# %%
queryData(con)
# Out:
# ----------------------------------------------------------------------------------------
#         name
# 0  reddit_vm
# 1   newtable
# SQL> select * from newtable
# ----------------------------------------------------------------------------------------
#                                                                             title  score       id                                                                                  url  comms_num       created                                                                                                                  body            timestamp
# 0                             Health Canada approves AstraZeneca COVID-19 vaccine      7   lt74vw          https://www.canadaforums.ca/2021/02/health-canada-approves-astrazeneca.html          0  1.614400e+09                                                                                                                  None  2021-02-27 06:33:45
# ...
